# %%
import pandas as pd
df = pd.read_csv('monitoreo_ambiental.csv')

# %%
df.describe()
# Out:
#        PM2_5_Ug_m3  Temperatura_C  Humedad_Relativa_Pct  Nivel_Ruido_dB
# count   500.000000     500.000000            500.000000      500.000000
# mean     80.810120      25.040200             61.604000       64.605600
# std      42.404804       7.500515             18.921608       14.127537
# min       5.780000      12.000000             30.000000       40.000000
# 25%      44.000000      18.800000             44.000000       53.025000
# 50%      84.595000      24.700000             61.500000       64.750000
# 75%     117.980000      31.500000             78.000000       76.600000
# max     149.650000      38.000000             94.000000       89.900000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID_Sensor                500 non-null    str
#  1   Ciudad                   500 non-null    str
#  2   Tipo_Zona                500 non-null    str
#  3   PM2_5_Ug_m3              500 non-null    float64
#  4   Temperatura_C            500 non-null    float64
#  5   Humedad_Relativa_Pct     500 non-null    int64
#  6   Presencia_Lluvia         500 non-null    bool
#  7   Nivel_Ruido_dB           500 non-null    float64
#  8   Indice_Calidad_Aire_ICA  500 non-null    str
#  9   Hora_Lectura             500 non-null    str
# dtypes: bool(1), float64(3), int64(1), str(5)
# memory usage: 58.7 KB
